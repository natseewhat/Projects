# %% [markdown]
# ## Importing Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# mounting of google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Importing of data

# %%
movies_df = pd.read_csv('/content/drive/MyDrive/Dataset/tmdb_5000_movies.csv')
credits_df = pd.read_csv('/content/drive/MyDrive/Dataset/tmdb_5000_credits.csv')

# %%
# confirming the dataset
print("Movies dataset:\n")
movies_df.head()
# Out:
# Movies dataset:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
print("\n Credits dataset:\n")
credits_df.head()
# Out:
#  Credits dataset:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %% [markdown]
# ## Dataset information

# %%
print("Shape of the Movies dataset:", movies_df.shape)

print("\nMovies Dataset info:\n")
movies_df.info()
# Out:
# Shape of the Movies dataset: (4803, 20)
#
# Movies Dataset info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
# ...

# %%
print("Shape of the Credits dataset:", credits_df.shape)

print("\nCredits Dataset info:\n")
credits_df.info()
# Out:
# Shape of the Credits dataset: (4803, 4)
#
# Credits Dataset info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4803 non-null   int64
#  1   title     4803 non-null   object
#  2   cast      4803 non-null   object
#  3   crew      4803 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 150.2+ KB

# %%
# check for any duplicates
print("Duplicate values in movies dataset:", movies_df.duplicated().sum())
print("Duplicate values in credits dataset:", credits_df.duplicated().sum())
# Out:
# Duplicate values in movies dataset: 0
# Duplicate values in credits dataset: 0

# %% [markdown]
# ## Merge Dataset

# %%
# rename credit dataset movie_id column to id
credits_df.rename(columns={'movie_id': 'id'}, inplace=True)

# %%
# confirm the rename column
credits_df.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
# merge movies and credits dataset
movies_df = movies_df.merge(credits_df, on='id')

# %%
# confirming the merge
movies_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %% [markdown]
# ## Data preparation

# %%
# turning json format column into a list
import re

def extract(s):
    # Check if the input string is not empty and contains valid JSON-like data
    if s and isinstance(s, str) and '{' in s and '}' in s:
        pattern = r'"name": "(.*?)"'
        return '|'.join(re.findall(pattern, s))
    else:
        return 'Unknown'

# %%
# applying extract to genre column
movies_df['genres'] = movies_df['genres'].apply(extract)

# extracting production company
movies_df['production_companies'] = movies_df['production_companies'].apply(extract)

# extracting name of director from crew column
movies_df['director'] = movies_df['crew'].apply(lambda x: [i['name'] for i in eval(x) if i['job'] == 'Director'])

# confirmation on the changes
movies_df.head()
# Out:
#       budget                                    genres  \
# 0  237000000  Action|Adventure|Fantasy|Science Fiction
# 1  300000000                  Adventure|Fantasy|Action
# 2  245000000                    Action|Adventure|Crime
# 3  250000000               Action|Crime|Drama|Thriller
# 4  260000000          Action|Adventure|Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# ...

# %%
# based on the info on release date column, there is 1 row with null values
# drop the null value on release date column
movies_df.dropna(subset=['release_date'], inplace=True)

#confirm changes
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4802 entries, 0 to 4802
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4802 non-null   int64
#  1   genres                4802 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4802 non-null   int64
#  4   keywords              4802 non-null   object
#  5   original_language     4802 non-null   object
#  6   original_title        4802 non-null   object
#  7   overview              4799 non-null   object
#  8   popularity            4802 non-null   float64
#  9   production_companies  4802 non-null   object
#  10  production_countries  4802 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4802 non-null   int64
#  13  runtime               4800 non-null   float64
#  14  spoken_languages      4802 non-null   object
# ...

# %%
# get the year from the release date
movies_df['release_year'] = pd.to_datetime(movies_df['release_date']).dt.year

# get the month from the release date
movies_df['release_month'] = pd.to_datetime(movies_df['release_date']).dt.month

# set the year and month to whole numbers
movies_df['release_year'] = movies_df['release_year'].astype(int)
movies_df['release_month'] = movies_df['release_month'].astype(int)

# confirm changes
movies_df.head()
# Out:
#       budget                                    genres  \
# 0  237000000  Action|Adventure|Fantasy|Science Fiction
# 1  300000000                  Adventure|Fantasy|Action
# 2  245000000                    Action|Adventure|Crime
# 3  250000000               Action|Crime|Drama|Thriller
# 4  260000000          Action|Adventure|Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# ...

# %%
# title_x  and title_y are the same to original title, therefore drop these columns
movies_df.drop(['title_x', 'title_y'], axis=1, inplace=True)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# library import for EDA
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# visualising the different genres
genres_df = movies_df[['id', 'genres']].copy()
# unselect unknown genres
genres_df = genres_df[genres_df['genres'] != 'Unknown']
# split the column
genres_df['genres'] = genres_df['genres'].str.split('|')
# explode the column
genres_df= genres_df.explode('genres')


# group and count the genres
genre_counts = genres_df.groupby('genres')['id'].count().sort_values(ascending=False)

print('Count of each genres:\n', genre_counts.to_string(header=False), "\n")

# plot the bar graph
plt.figure(figsize=(12, 6))
plt.bar(genre_counts.index, genre_counts.values)
plt.xlabel("Genre")
plt.ylabel("Number of Movies")
plt.title("Distribution of Movie Genres")
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.tight_layout()  # Adjust layout to prevent overlapping elements
plt.show()
# Out:
# Count of each genres:
#  Drama              2297
# Comedy             1722
# Thriller           1274
# Action             1154
# Romance             894
# Adventure           790
# Crime               696
# Science Fiction     535
# Horror              519
# Family              513
# Fantasy             424
# Mystery             348
# Animation           234
# History             197
# Music               185
# War                 144
# Documentary         110
# Western              82
# Foreign              34
# TV Movie              8

# %%
# visualise the different production company
production_companies_df = movies_df[['id', 'production_companies']].copy()
# unselect Unknown production companies values
production_companies_df = production_companies_df[production_companies_df['production_companies'] != 'Unknown']
# split the column
production_companies_df['production_companies'] = production_companies_df['production_companies'].str.split('|')
# explode the column
production_companies_df = production_companies_df.explode('production_companies')

# group and count the genres
production_company_counts = production_companies_df.groupby('production_companies')['id'].count().sort_values(ascending=False)

# Showing the Top 10 Companies
top_10_companies = production_company_counts.head(10)
print('Top 10 Production Companies:\n', top_10_companies.to_string(header=False), "\n")


# plot the bar graph
plt.figure(figsize=(12, 6))
plt.bar(top_10_companies.index, top_10_companies.values)
plt.xlabel("Production Company")
plt.ylabel("Number of Movies")
plt.title("Top 10 Production Company")
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.tight_layout()  # Adjust layout to prevent overlapping elements
plt.show()
# Out:
# Top 10 Production Companies:
#  Warner Bros.                              319
# Universal Pictures                        311
# Paramount Pictures                        285
# Twentieth Century Fox Film Corporation    222
# Columbia Pictures                         201
# New Line Cinema                           165
# Metro-Goldwyn-Mayer (MGM)                 122
# Touchstone Pictures                       118
# Walt Disney Pictures                      114
# Relativity Media                          102

# %%
# visualise the count on director
director_df = movies_df[['id', 'director']].copy()

# Convert the 'director' column to strings before grouping
# Assuming each movie has only one primary director and you want to analyze based on that:
director_df['director'] = director_df['director'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else 'Unknown')

# unselect Unknown director values
director_df = director_df[director_df['director'] != 'Unknown']

# group and count director
director_counts = director_df.groupby('director')['id'].count().sort_values(ascending=False)

# Select the Top 20 Director
top_20_directors = director_counts.head(20)
print('Top 20 Directors:\n', top_20_directors.to_string(header=False), "\n")

# plot the bar graph
plt.figure(figsize=(12, 6))
plt.bar(top_20_directors.index, top_20_directors.values)
plt.xlabel("Director")
plt.ylabel("Number of Movies")
plt.title("Top 20 Directors")
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.tight_layout()  # Adjust layout to prevent overlapping elements
plt.show()
# Out:
# Top 20 Directors:
#  Steven Spielberg        27
# Woody Allen             21
# Martin Scorsese         20
# Clint Eastwood          20
# Spike Lee               16
# Robert Rodriguez        16
# Ridley Scott            16
# Renny Harlin            15
# Steven Soderbergh       15
# Oliver Stone            14
# Tim Burton              14
# Robert Zemeckis         13
# Ron Howard              13
# Joel Schumacher         13
# Barry Levinson          13
# Michael Bay             12
# Tony Scott              12
# Francis Ford Coppola    12
# Brian De Palma          12
# Kevin Smith             12

# %%
# find the revenue over the years
movies_revenue = movies_df[['production_companies','release_year', 'revenue']].copy()
movies_revenue = movies_revenue.groupby('release_year')['revenue'].sum()


# plot in a bar graph
plt.figure(figsize=(12, 6))
plt.bar(movies_revenue.index, movies_revenue.values)
plt.xlabel("Year")
plt.ylabel("Total Revenue")
plt.title("Movie Revenue Over the Years")
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.tight_layout()  # Adjust layout to prevent overlapping elements
plt.show()

# %%
# find the revenue for each production company
companies_revenue = movies_df[['production_companies', 'revenue']].copy()

# unselect Unknown production companies values
companies_revenue = companies_revenue[companies_revenue['production_companies'] != 'Unknown']

# split the column
companies_revenue['production_companies'] = companies_revenue['production_companies'].str.split('|')

# explode the column
companies_revenue = companies_revenue.explode('production_companies')

# revenue by production company
movies_revenue_by_companies = companies_revenue.groupby('production_companies')['revenue'].sum()

# showing Top 10 Companies
top_10_earning_companies = movies_revenue_by_companies.sort_values(ascending=False).head(10)
print('Top 10 Production Companies:\n', top_10_earning_companies.to_string(header=False), "\n")


# plot the bar graph
plt.figure(figsize=(12, 6))
plt.bar(top_10_earning_companies.index, top_10_earning_companies.values)
plt.xlabel("Production Companies")
plt.ylabel("Total Revenue")
plt.title("Top 10 Highest Revenue Companies")
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.tight_layout()  # Adjust layout to prevent overlapping elements
plt.show()
# Out:
# Top 10 Production Companies:
#  Warner Bros.                              49155747874
# Universal Pictures                        42588465942
# Paramount Pictures                        40878523165
# Twentieth Century Fox Film Corporation    39357151309
# Walt Disney Pictures                      28683256048
# Columbia Pictures                         28599634775
# New Line Cinema                           19444865804
# Amblin Entertainment                      16090835147
# DreamWorks SKG                            14384533626
# Dune Entertainment                        13797504190

# %%
# EDA on movies
movies_comparison_df = movies_df[['original_title', 'budget', 'revenue', 'popularity']].copy()

# Top 10 Movies with higest revenue
movies_by_revenue = movies_comparison_df.sort_values(by='revenue', ascending=False).head(10)

# Top 10 Movies with highest popularity
movies_by_popularity = movies_comparison_df.sort_values(by='popularity', ascending=False).head(10)

# Top 10 Movies with higest budget
movies_by_budget = movies_comparison_df.sort_values(by='budget', ascending=False).head(10)

# plot the 3 different bar graph
# Revenue
plt.figure(figsize=(12, 6))
plt.barh(movies_by_revenue['original_title'], movies_by_revenue['revenue'], label='Revenue')
plt.xlabel("Revenue")
plt.ylabel("Movies")
plt.title("Highest Revenue Movies")
plt.tight_layout()  # Adjust layout to prevent overlapping elements
plt.show()

print("\n")

# Popularity
plt.figure(figsize=(12, 6))
plt.barh(movies_by_popularity['original_title'], movies_by_popularity['popularity'], label='Popularity')
plt.xlabel("Popularity")
plt.ylabel("Movies")
plt.title("Highest Popularity Movies")
plt.tight_layout()  # Adjust layout to prevent overlapping elements
plt.show()

print("\n")

# Budget
plt.figure(figsize=(12, 6))
plt.barh(movies_by_budget['original_title'], movies_by_budget['budget'], label='Budget')
plt.xlabel("Budget")
plt.ylabel("Movies")
plt.title("Highest Budget Movies")
plt.tight_layout()  # Adjust layout to prevent overlapping elements
plt.show()

# %% [markdown]
# ## Recommender System using Cosine Similarity

# %%
# Selecting the needed columns as a copy
movies2_df = movies_df[['id', 'original_title', 'production_companies', 'director', 'genres']].copy()

# confirmation
movies2_df.head()
# Out:
#        id                            original_title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                 production_companies             director  \
# 0  Ingenious Film Partners|Twentieth Century Fox ...      [James Cameron]
# 1  Walt Disney Pictures|Jerry Bruckheimer Films|S...     [Gore Verbinski]
# 2                       Columbia Pictures|Danjaq|B24         [Sam Mendes]
# 3  Legendary Pictures|Warner Bros.|DC Entertainme...  [Christopher Nolan]
# 4                               Walt Disney Pictures     [Andrew Stanton]
#
#                                      genres
# 0  Action|Adventure|Fantasy|Science Fiction
# 1                  Adventure|Fantasy|Action
# 2                    Action|Adventure|Crime
# ...

# %% [markdown]
# ### Recommender System based on genres

# %%
# fit director data into matrix
from sklearn.feature_extraction.text import CountVectorizer

#Define a new CountVectorizer object and create vectors for the director
count_vectorizer = CountVectorizer(stop_words='english')

#Replace NaN with an empty string
movies2_df['genres'] = movies2_df['genres'].fillna('')

#Construct the required TF-IDF matrix by fitting and transforming the data
genres_count_matrix = count_vectorizer.fit_transform(movies2_df['genres'])

# get the shape of matrix
genres_count_matrix.shape
# Out:
# (4802, 23)

# %%
# Compute the cosine similarity matrix
from sklearn.metrics.pairwise import cosine_similarity
genres_cosine_sim = cosine_similarity(genres_count_matrix, genres_count_matrix)

# %%
#Construct a reverse map of indices and movie titles
indices = pd.Series(movies2_df.index, index=movies2_df['original_title']).drop_duplicates()

# %%
# Function that takes in movie title as input and outputs most similar movies
def movies_recommendations(title, cosine_sim):
    # Get the index of the movie that matches the title
    idx = indices[title]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return movies2_df['original_title'].iloc[movie_indices]

# %%
# testing the system
movies_recommendations('Superman Returns', genres_cosine_sim)
# Out:
# 10                               Superman Returns
# 14                                   Man of Steel
# 46                     X-Men: Days of Future Past
# 61                              Jupiter Ascending
# 232                                 The Wolverine
# 813                                      Superman
# 870                                   Superman II
# 3494    Beastmaster 2: Through the Portal of Time
# 72                                  Suicide Squad
# 238                  Teenage Mutant Ninja Turtles
# Name: original_title, dtype: object

# %%
movies_recommendations('Tangled', genres_cosine_sim)
# Out:
# 34                    Monsters University
# 57                                 WALL·E
# 120           Madagascar: Escape 2 Africa
# 137                       Kung Fu Panda 2
# 146    Madagascar 3: Europe's Most Wanted
# 177                                 Turbo
# 194                              Dinosaur
# 255                     Home on the Range
# 328                          Finding Nemo
# 430                         Lilo & Stitch
# Name: original_title, dtype: object

# %% [markdown]
# ### Recommender System based on Director

# %%
# Convert the 'director' column to a string representation before fitting
movies2_df['director'] = movies2_df['director'].apply(lambda x: ' '.join(x) if isinstance(x, list) else str(x))

# Transform the data
director_count_matrix = count_vectorizer.fit_transform(movies2_df['director'])

# Fitting to cosine_sim
director_cosine_sim = cosine_similarity(director_count_matrix, director_count_matrix)

# %%
movies_recommendations('Deadpool', director_cosine_sim)
# Out:
# 32                   Alice in Wonderland
# 117    Charlie and the Chocolate Factory
# 127                   Mad Max: Fury Road
# 133                         Dark Shadows
# 173                       Happy Feet Two
# 184                                 Home
# 187                        Puss in Boots
# 215         4: Rise of the Silver Surfer
# 278                   Planet of the Apes
# 385                           Happy Feet
# Name: original_title, dtype: object

# %%
movies_recommendations('The Avengers', director_cosine_sim)
# Out:
# 16                                  The Avengers
# 1294                                    Serenity
# 0                                         Avatar
# 1       Pirates of the Caribbean: At World's End
# 2                                        Spectre
# 3                          The Dark Knight Rises
# 4                                    John Carter
# 5                                   Spider-Man 3
# 6                                        Tangled
# 8         Harry Potter and the Half-Blood Prince
# Name: original_title, dtype: object

# %% [markdown]
# ### Recommendations System based on Production Companies

# %%
# setting on production companies
pc_count_matrix = count_vectorizer.fit_transform(movies2_df['production_companies'])

# Fitting to cosine_sim
pc_cosine_sim = cosine_similarity(pc_count_matrix, pc_count_matrix)

# %%
# Testing the system
movies_recommendations('Deadpool', pc_cosine_sim)
# Out:
# 64                    X-Men: Apocalypse
# 3355                        Devil's Due
# 91         Independence Day: Resurgence
# 3029           Kung Pow: Enter the Fist
# 1111                Victor Frankenstein
# 242                      Fantastic Four
# 232                       The Wolverine
# 766     Garfield: A Tail of Two Kitties
# 46           X-Men: Days of Future Past
# 282                           True Lies
# Name: original_title, dtype: object

# %%
movies_recommendations('John Carter', pc_cosine_sim)
# Out:
# 255                            Home on the Range
# 288                  The Hunchback of Notre Dame
# 465                                Fantasia 2000
# 646                                      The Kid
# 752                          My Favorite Martian
# 1045    The Princess Diaries 2: Royal Engagement
# 1055                                 The Muppets
# 1206               The Odd Life of Timothy Green
# 1496                                   Snow Dogs
# 1595                                  Glory Road
# Name: original_title, dtype: object

# %% [markdown]
# ### Combine all 3 into a recommendation system

# %%
# create a column to join genre, production companies and director colunmn
movies2_df['combined_features'] = movies2_df['genres'] + ' ' + movies2_df['production_companies'] + ' ' + movies2_df['director']

# confirm
movies2_df['combined_features'].head()
# Out:
# 0    Action|Adventure|Fantasy|Science Fiction Ingen...
# 1    Adventure|Fantasy|Action Walt Disney Pictures|...
# 2    Action|Adventure|Crime Columbia Pictures|Danja...
# 3    Action|Crime|Drama|Thriller Legendary Pictures...
# 4    Action|Adventure|Science Fiction Walt Disney P...
# Name: combined_features, dtype: object

# %%
# transform the data
combined_count_matrix = count_vectorizer.fit_transform(movies2_df['combined_features'])

# Fitting to cosine_sim
combined_cosine_sim = cosine_similarity(combined_count_matrix, combined_count_matrix)

# %%
# testing the system
movies_recommendations('Deadpool', combined_cosine_sim)
# Out:
# 64                            X-Men: Apocalypse
# 242                              Fantastic Four
# 3029                   Kung Pow: Enter the Fist
# 91                 Independence Day: Resurgence
# 232                               The Wolverine
# 766             Garfield: A Tail of Two Kitties
# 46                   X-Men: Days of Future Past
# 1918                Big Trouble in Little China
# 195     Night at the Museum: Secret of the Tomb
# 819                                  Date Night
# Name: original_title, dtype: object

# %%
movies_recommendations('Avatar', combined_cosine_sim)
# Out:
# 1652              Dragonball Evolution
# 587                          The Abyss
# 282                          True Lies
# 335     Rise of the Planet of the Apes
# 101                 X-Men: First Class
# 292                             Eragon
# 507                   Independence Day
# 91        Independence Day: Resurgence
# 1201                         Predators
# 243                Night at the Museum
# Name: original_title, dtype: object
